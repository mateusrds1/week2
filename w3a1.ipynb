# %% [markdown]
# <a href="https://colab.research.google.com/github/mateusrds1/week2/blob/main/w3a1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

# %%
def maximum(values):
    answer = None
    for x in values:
        if answer == None or answer < x:
          answer = x
    return answer

test_values =[4, 3, 5, 6, 2, 1]
print(test_values)

max_value = maximum(test_values)
print("O Valor max eh: ")
print(max_value)

# %%
def maximum(values):
    answer = None
    for x in values:
        if answer == None or answer < x:
          answer = x
    return answer

def gen_input(length):
    return [random.randint(-1000, 1000) for _ in range(length)]

start = time.time()
max_value = maximum(test_values)
end = time.time()
runtime = end - start

print("O Tempo eh: ")
print(runtime)
# Out:
# O Tempo eh:
# 0.00017642974853515625

# %%
import time
import random

def maximum(values):
    answer = None
    for value in values:
        if answer == None or answer < value:
            answer = value
    return answer

# add your code below
times = []
def gen_input(length):
    return [random.randint(-1000, 1000) for _ in range(length)]

for lenght in range(1,501):
  values = gen_input(lenght)
  start = time.time()
  maximum(values)
  end = time.time()
  times.append(end - start)
print(times)
# Out:
# [1.1920928955078125e-06, 1.6689300537109375e-06, 1.1920928955078125e-06, 1.1920928955078125e-06, 1.1920928955078125e-06, 1.6689300537109375e-06, 1.430511474609375e-06, 1.1920928955078125e-06, 1.6689300537109375e-06, 2.1457672119140625e-06, 1.6689300537109375e-06, 2.384185791015625e-06, 2.384185791015625e-06, 2.384185791015625e-06, 2.384185791015625e-06, 2.6226043701171875e-06, 3.0994415283203125e-06, 3.0994415283203125e-06, 3.0994415283203125e-06, 3.337860107421875e-06, 3.337860107421875e-06, 3.337860107421875e-06, 3.337860107421875e-06, 3.814697265625e-06, 3.5762786865234375e-06, 3.814697265625e-06, 4.0531158447265625e-06, 3.814697265625e-06, 4.291534423828125e-06, 4.291534423828125e-06, 4.76837158203125e-06, 4.291534423828125e-06, 4.5299530029296875e-06, 4.76837158203125e-06, 5.245208740234375e-06, 5.4836273193359375e-06, 5.4836273193359375e-06, 4.5299530029296875e-06, 5.7220458984375e-06, 5.4836273193359375e-06, 4.291534423828125e-06, 4.76837158203125e-06, 5.0067901611328125e-06, 5.0067901611328125e-06, 5.4836273193359375e-06, 6.9141387939453125e-06, 6.9141387939453125e-06, 6.4373016357421875e-06, 7.152557373046875e-06, 6.4373016357421875e-06, 7.62939453125e-06, 7.62939453125e-06, 7.3909759521484375e-06, 7.867813110351562e-06, 7.867813110351562e-06, 6.9141387939453125e-06, 8.106231689453125e-06, 7.152557373046875e-06, 7.62939453125e-06, 7.867813110351562e-06, 7.152557373046875e-06, 8.58306884765625e-06, 5.4836273193359375e-06, 5.245208740234375e-06, 5.0067901611328125e-06, 5.245208740234375e-06, 5.4836273193359375e-06, 5.245208740234375e-06, 5.4836273193359375e-06, 5.4836273193359375e-06, 7.152557373046875e-06, 5.7220458984375e-06, 5.7220458984375e-06, 5.4836273193359375e-06, 5.9604644775390625e-06, 5.9604644775390625e-06, 6.198883056640625e-06, 1.049041748046875e-05, 1.1444091796875e-05, 8.821487426757812e-06, 1.0251998901367188e-05, 1.0728836059570312e-05, 1.0967254638671875e-05, 1.1920928955078125e-05, 9.775161743164062e-06, 9.059906005859375e-06, 1.2874603271484375e-05, 1.3113021850585938e-05, 1.1205673217773438e-05, 1.4066696166992188e-05, 1.4066696166992188e-05, 1.1444091796875e-05, 9.775161743164062e-06, 1.0013580322265625e-05, 1.5020370483398438e-05, 1.3113021850585938e-05, 1.1920928955078125e-05, 1.1205673217773438e-05, 1.3113021850585938e-05, 1.2159347534179688e-05, 1.3589859008789062e-05, 1.1205673217773438e-05, 1.2636184692382812e-05, 8.106231689453125e-06, 7.867813110351562e-06, 7.867813110351562e-06, 8.106231689453125e-06, 8.58306884765625e-06, 8.106231689453125e-06, 1.1682510375976562e-05, 8.821487426757812e-06, 8.821487426757812e-06, 8.344650268554688e-06, 1.4543533325195312e-05, 1.2874603271484375e-05, 9.059906005859375e-06, 8.58306884765625e-06, 9.059906005859375e-06, 9.298324584960938e-06, 8.821487426757812e-06, 9.298324584960938e-06, 9.298324584960938e-06, 9.059906005859375e-06, 9.298324584960938e-06, 9.5367431640625e-06, 9.5367431640625e-06, 9.775161743164062e-06, 9.5367431640625e-06, 9.775161743164062e-06, 9.775161743164062e-06, 1.0013580322265625e-05, 1.0251998901367188e-05, 1.0013580322265625e-05, 1.0251998901367188e-05, 1.0013580322265625e-05, 1.049041748046875e-05, 1.049041748046875e-05, 1.049041748046875e-05, 1.0251998901367188e-05, 1.0251998901367188e-05, 1.0728836059570312e-05, 1.0728836059570312e-05, 1.0728836059570312e-05, 1.0728836059570312e-05, 1.0728836059570312e-05, 1.0728836059570312e-05, 1.1205673217773438e-05, 1.0967254638671875e-05, 1.1205673217773438e-05, 1.1920928955078125e-05, 1.1920928955078125e-05, 1.1444091796875e-05, 1.1444091796875e-05, 1.1444091796875e-05, 1.1444091796875e-05, 1.1444091796875e-05, 1.1682510375976562e-05, 1.1682510375976562e-05, 1.1920928955078125e-05, 1.2159347534179688e-05, 1.1682510375976562e-05, 1.2159347534179688e-05, 1.239776611328125e-05, 1.1920928955078125e-05, 1.239776611328125e-05, 1.239776611328125e-05, 1.2636184692382812e-05, 1.2636184692382812e-05, 1.2636184692382812e-05, 1.2636184692382812e-05, 1.2636184692382812e-05, 1.3113021850585938e-05, 1.263 ...

# %%
def plot_times(times):
    plt.plot(times)
    plt.ylabel('runtime')
    plt.xlabel('size')
    plt.show()

def sum_values(values):
    total = 0
    for value in values:
        total += value
    return total

def gen_input(length):
    return [random.randint(-1000, 1000) for _ in range(length)]

# add your code below

times = []
for lenght in range(1,501):
  values = gen_input(lenght)
  start = time.time()
  maximum(values)
  end = time.time()
  times.append(end - start)
plot_times(times)

# %%
def count_zeros(values):
    count = 0            # c1 1
    for value in values: # c2 N
        if value == 0:   # c3 N
            count += 1   # c4 N
    return count         # c5 1

model1 = '(c1 + c2) * N + (c3 + c4 + c5)'
model2 = '(c2 + c3) * N + (c1 + c4 + c5)'
model3 = '(c2 + c3 + c4) * N + (c1 + c5)' #Correct

correct = model3

# %%
def sum_pairs(values):
    pair_sums = 0              # c1 1
    for x in values:           # c2 N
        for y in values:       # c3 N^2
            pair_sums += x + y # c4 N^2
    return pair_sums           # c5 1

model1 = '(c3 + c4) * N^2 + c2 * N + (c1 + c5)' #correct
model2 = 'c4 * N^2 + (c2 + c3) * N + (c1 + c5)'
model3 = '(c2 + c3 + c4) * N^2 + (c1 + c5)'

correct = model1

# %%
time1 = 'N^4 + N^2 + 1'
time2 = '7 * N^3 + 0.5 * N^2 + 100'
time3 = 'N^2 + 10000 * N + 999'

# O1 = O(N^4)
# O2 = O(N^3)
# O3 = O(N^2)

# %%
def count_triples(values):
    count = 0                                                #1
    N = len(values)                                          #1
    for i in range(N):                                       #N
        for j in range(N):                                   #N^2
            for k in range(N):                               #N^3
                if values[i] + values[j] + values[k] == 0:   #N^3
                    count += 1                               #N^3
    return count                                             #1

#1 + 1 + N + N² + N³ + N³ + N³ + N³ + 1 ==> 3N³ + N² + N + 3
coefficients = [3, 1, 1, 3]
ordem = "O(N³)"
